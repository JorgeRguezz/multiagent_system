# %%
import json

knowledge_path = "/home/gatv-projects/Desktop/project/knowledge_extraction/cache/kv_store_video_segments.json"

with open(knowledge_path, "r") as f:
    knowledge_json = json.load(f)

i = 0

for video in knowledge_json.values():
    for segment in video.values():
        print(segment["time"])
        i += 1
print("Bien") if i == 6 else print("Mal")
# Out:
# 0-30
# 30-60
# 60-90
# 90-120
# 120-150
# 150-180
# Bien

# %%
knowledge_path = "/home/gatv-projects/Desktop/project/knowledge_extraction/cache/kv_store_video_frames.json"

with open(knowledge_path, "r") as f:
    knowledge_json = json.load(f)

segment_content = []
i = 0

for video in knowledge_json.values():
    for segment in video.values():
        if i <= 4:
            i += 1
            segment_content.append(segment["vlm_output"])


print(segment_content)
print("----->", i)
# Out:
# ["**Dynamic Events:**\n- No banners, gold numbers, or kill notifications are visible in the current frame.\n\n**Action-State:**\n- The character, Smolder, is in a neutral stance, likely preparing for movement or an ability cast. There is no specific ability being cast at this moment.\n\n**Player State:**\n- The HUD is not visible in this frame, so current level, health percentage, and mana percentage cannot be reported.\n\n**Map Logic:**\n- Smolder is positioned near a river in a forested area, possibly preparing to move towards a specific objective or engage in combat. There are no visible minions or other champions in the immediate vicinity.\n\n**Transcript Tie-In:**\n- The transcript mentions that this guide will cover everything needed to get started with Smolder, including playstyle, ability breakdowns, combos, and tips. The current frame shows Smolder in a neutral stance, which aligns with the guide's focus on understanding the champion's basic movements and positioning before engaging in combat or executing combos. This visual can be used to emphasize the importance of understanding Smolder's base movements and readiness for action, as highlighted in the transcript's tactical advice.", "**Dynamic Events:**\n- No banners, gold numbers, or kill notifications are visible in the current frame.\n\n**Action-State:**\n- Smolder is actively engaged in combat, using an ability that creates a fiery effect around him. The ability appears to be targeting the opposing champion, who is positioned near a turret.\n\n**Player State:**\n- The HUD is not visible in this frame, so current level, health percentage, and mana percentage cannot be reported.\n\n**Map Logic:**\n- Smolder is advancing towards the turret in the bottom lane, engaging with an enemy champion. Minions are present and moving towards the turret, indicating ongoing lane pressure. The opposing champion is attempting to defend the turret while being attacked by Smolder.\n\n**Transcript Tie-In:**\n- The transcript emphasizes Smolder's strength in lower elo brackets and the importance of understanding his playstyle and combos. The current frame shows Smolder executing a combo or ability in a fight, which aligns with the guide's focus on mastering his combat techniques. This visual demonstrates the practical application of the guide's tactical advice, highlighting Smolder's aggressive playstyle and ability to dominate in lane skirmishes.", '**Dynamic Events:**\n- No banners, gold numbers, or kill notifications are visible in the current frame.\n\n**Action-State:**\n- The scene is a static title card for a "Smolder Starter Guide," indicating a transition from gameplay to instructional content. There are no active combat events or ability casts.\n\n**Player State:**\n- Since this is a title card, there is no HUD visible, and thus no player state information such as level, health, or mana can be reported.\n\n**Map Logic:**\n- The background shows a blurred game map, but no specific movements of minions or champions can be discerned due to the static nature of the frame.\n\n**Transcript Tie-In:**\n- The transcript mentions that the guide will cover Smolder\'s playstyle, ability breakdowns, combos, and more. The current frame serves as an introduction to this comprehensive guide, setting the stage for the detailed tactical advice that follows. This aligns with the guide\'s promise to provide everything needed to get started with Smolder, emphasizing the importance of understanding his capabilities and strategies.\n\n**Scene description:**\n- The frame displays a title card for a "Smolder Starter Guide" with a shield icon and the text "Smolder" prominently featured. The background is a blurred game map, and the design includes geometric elements and an orange accent. This indicates a shift from gameplay to instructional content, preparing the viewer for the detailed guide on Smolder\'s champion abilities and strategies.', '**Dynamic Events:**\n- No banners, gold numbers, or kill no ...
# -----> 5
